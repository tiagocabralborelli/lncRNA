# %% [markdown]
# **mzTbs**
#
# _General_
#
# mzTab is meant to be a light-weight, tab-delimited file format for proteomics data. The target audience for this format are primarily researchers outside of proteomics. It should be easy to parse and only contain the minimal information required to evaluate the results of a proteomics experiment. The aim of the format is to present the results of a proteomics experiment in a computationally accessible overview. The aim is not to provide the detailed evidence for these results, or allow recreating the process which led to the results. Both of these functions are established through links to more detailed representations in other formats, in particular mzIdentML and mzQuantML [Ref1](https://code.google.com/archive/p/mztab/). Besides, mzTab can be used alone or with those other formats [Ref2](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4189001/)
#
# **Warning**:Although mzTab can be used to report a detailed view on data, it explicitly does not aim to capture the whole complexity and evidence trail of a proteomics study. Even the most complex mzTab files still include simplifications/assumptions of the experimental results. This, for instance, is the case in identification (e.g. protein inference/grouping is only supported to a limited extent) and quantification results (e.g. the coordinates for isotope patterns in quantified two-dimensional “features” cannot be fully reported). This missing information can be reported using the existing PSI standard formats mzIdentML and mzQuantML.
#
# _File content_
#
# Section:
# - MTD: metadata - was deliberately kept flexible, and the majority of fields are optional. Therefore, it is possible to report different levels of experimental annotation depending on the interest of the producer of the files, ranging from basic annotations to the complete
# - PRH: protein hearder
# - PRT: protein identifications
# - PEH: peptide header
# - PEP: peptide identifications
# - PSH: peptide-spectrum  hearder
# - PSM: peptide-spectrum match - indicates whether the peptides were unambiguously assigned to a given protein.
# - SMH: small molecules hearder  - is used to report aggregated quantification data based on several PSMs.
# - SML: small molecules identifications
# - COM: comments
#
#
# <!-- ![Fig1](/home/tiago/documents/lncRNA/Study/Fig1_mztabe_content.jpg) -->

# %%
from pyteomics import mztab

# %%
mztab = mztab.MzTab("/home/tiagoborelli/Documentos/lncRNA/coffie/generated/2experimentos.pride.mztab")

# %%
mztab.keys()
# Out:
# odict_keys(['PRT', 'PEP', 'PSM', 'SML'])

# %%
mztab.metadata
# Out:
# OrderedDict([('mzTab-version', 1.0),
#              ('mzTab-mode', 'Complete'),
#              ('mzTab-type', 'Identification'),
#              ('mzTab-ID', 'PXD002963-58016'),
#              ('title', 'no assay title provided (mzIdentML)'),
#              ('description',
#               'Coffee is one of the most important commodities cultivated worldwide and has great economic impact in producing countries. Although 130 different species belonging to the coffea gender have been described, only two of them are commercially exploited: Coffea arabica and Coffea canephora. C. arabica is responsible for 61% of the world production (Van der Vossen et al., 2015). However, due to the narrow genetic back ground, classical genetic breeding is time consuming and takes around 30 years (Santana-Buzzy et al., 2007; Hendre et al., 2014). Several genetic engineering and biotechnological tools have been successfully applied in coffee breeding. Somatic embryogenesis (SE) is a process in which new viable embryos are produced from somatic tissues. It is one of the most promising production processes (Santana-Buzzy et al, 2007; Marsoni et al., 2008). A better understanding of the molecular basis related to somatic embryogenesis will give insight into the process of embryo formation and totipotency and will allow the development of new in vitro culture strategies for the propagation and genetic manipulation of elite cultivars (Marsoni et al., 2008). High throughput proteomics in coffee is limited so far to 2D gel based proteomics techniques. Although really useful and the most common technique for plants, 2DE is limited in throughput and a gel free technique allow to go a step further (Carpentier & America, 2014; Vanhove et al., 2015). To improve the knowledge about somatic embryogenesis, we present the first high throughput proteome profile (1051 confident protein identifications) of coffee embryogenic cell suspensions developed from leaves of Coffea arabica cultivar Catuaí.'),
#              ('instrument[1]-name', 'instrument model'),
#              ('software[1]', ('Mascot', '2.2.06')),
#              ('software[2]', ('Scaffold', 'Scaffold_4.4.5')),
#              ('software[2]-setting[1]', 'Scaffold: Minimum Peptide Count = 1'),
#              ('software[2]-setting[2]',
#               'Scaffold: Minimum Protein Probability = 0.2'),
#              ('software[2]-setting[3]',
#               'Scaffold: Minimum Peptide Probability = 0.95'),
#              ('software[2]-setting[4]',
#               'minimum number of enzymatic termini = 0'),
#              ('software[2]-setting[5]',
#               'Scaffold:Samples In Mudpit Mode = none'),
#              ('software[2]-setting[6]',
#               'Scaffold:Samples In Condense Data Mode = File Name: nadia_sample_01.raw (F019845);File Name: nadia_sample_02.raw (F019833);File Name: nadia_sample_02.raw (F019846);File Name: nadia_sample_03.raw (F019834);File Name: nadia_sample_03.raw (F019847);File Name: nadia_sample_04.raw (F019835);File Name: nadia_sample_04.raw (F019848);File Name: nadia_sample_05.raw (F019836);File Name: nadia_sample_05.raw (F019849);File Name: nadia_sample_06.raw (F019850);File Name: nadia_sample_06.raw (F019850_1);File Name: nadia_sample_07.raw (F019838);File Name: nadia_sample_07.raw (F019851);File Name: nadia_sample_08.raw (F019852);File Name: nadia_sample_09.raw (F019839);File Name: nadia_sample_09.raw (F019853);File Name: nadia_sample_10.raw (F019840);File Name: nadia_sample_10.raw (F019854);File Name: nadia_sample_11.raw (F019855);File Name: nadia_sample_12.raw (F019841_1);File Name: nadia_sample_12.raw (F019856)'),
#              ('software[2]-setting[7]', 'Scaffold:Experiment View Filter ='),
#              ('software[2]-setting[8]',
#               'Scaffold:Show Hidden Proteins = false'),
#              ('software[2]-setting[9]',
#               'Scaffold:Show Decoy Identifications = true'),
#              ('software[2]-setting[10]', 'no threshold'),
#              ('software[2]-setting[11]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[12]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[13]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[14]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[15]', 'no threshold'),
#              ('software[2]-setting[16]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[17]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[18]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[19]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[20]', 'no threshold'),
#              ('software[2]-setting[21]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[22]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[23]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[24]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[25]', 'no threshold'),
#              ('software[2]-setting[26]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[27]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[28]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[29]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[30]', 'no threshold'),
#              ('software[2]-setting[31]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[32]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[33]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[34]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[35]', 'no threshold'),
#              ('software[2]-setting[36]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[37]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[38]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[39]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[40]', 'no threshold'),
#              ('software[2]-setting[41]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[42]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[43]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[44]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[45]', 'no threshold'),
#              ('software[2]-setting[46]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[47]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[48]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[49]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[50]', 'no threshold'),
#              ('software[2]-setting[51]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[52]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[53]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[54]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[55]', 'no threshold'),
#              ('software[2]-setting[56]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[57]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[58]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[59]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[60]', 'no threshold'),
#              ('software[2]-setting[61]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[62]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[63]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[64]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[65]', 'no threshold'),
#              ('software[2]-setting[66]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[67]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[68]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[69]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[70]', 'no threshold'),
#              ('software[2]-setting[71]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[72]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[73]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[74]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[75]', 'no threshold'),
#              ('software[2]-setting[76]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[77]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[78]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[79]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[80]', 'no threshold'),
#              ('software[2]-setting[81]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[82]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[83]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[84]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[85]', 'no threshold'),
#              ('software[2]-setting[86]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[87]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[88]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[89]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[90]', 'no threshold'),
#              ('software[2]-setting[91]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[92]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[93]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[94]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[95]', 'no threshold'),
#              ('software[2]-setting[96]', 'search tolerance plus value = 0.01'),
#              ('software[2]-setting[97]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[98]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[99]', 'search tolerance minus value = 5.0'),
#              ('software[2]-setting[100]', 'no threshold'),
#              ('software[2]-setting[101]',
#               'search tolerance plus value = 0.01'),
#              ('software[2]-setting[102]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[103]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[104]',
#               'search tolerance minus value = 5.0'),
#              ('software[2]-setting[105]', 'no threshold'),
#              ('software[2]-setting[106]',
#               'search tolerance plus value = 0.01'),
#              ('software[2]-setting[107]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[108]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[109]',
#               'search tolerance minus value = 5.0'),
#              ('software[2]-setting[110]', 'no threshold'),
#              ('software[2]-setting[111]',
#               'search tolerance plus value = 0.01'),
#              ('software[2]-setting[112]',
#               'search tolerance minus value = 0.01'),
#              ('software[2]-setting[113]', 'search tolerance plus value = 5.0'),
#              ('software[2]-setting[114]',
#               'search tolerance minus value = 5.0'),
#              ('software[3]', ('X\\!Tandem', 'CYCLONE (2010.12.01.1)')),
#              ('protein_search_engine_score[1]',
#               'Scaffold:Protein Probability'),
#              ('psm_search_engine_score[1]', 'Mascot:score'),
#              ('psm_search_engine_score[2]', 'Mascot:identity threshold'),
#              ('psm_search_engine_score[3]', 'Scaffold:Peptide Probability'),
#              ('psm_search_engine_score[4]', 'X!Tandem:expect'),
#              ('uri[1]', 'http://www.ebi.ac.uk/pride/archive/assays/58016'),
#              ('fixed_mod[1]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[1]-site', 'C'),
#              ('fixed_mod[2]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[2]-site', 'C'),
#              ('fixed_mod[3]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[3]-site', 'C'),
#              ('fixed_mod[4]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[4]-site', 'C'),
#              ('fixed_mod[5]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[5]-site', 'C'),
#              ('fixed_mod[6]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[6]-site', 'C'),
#              ('fixed_mod[7]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[7]-site', 'C'),
#              ('fixed_mod[8]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[8]-site', 'C'),
#              ('fixed_mod[9]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[9]-site', 'C'),
#              ('fixed_mod[10]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[10]-site', 'C'),
#              ('fixed_mod[11]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[11]-site', 'C'),
#              ('fixed_mod[12]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[12]-site', 'C'),
#              ('fixed_mod[13]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[13]-site', 'C'),
#              ('fixed_mod[14]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[14]-site', 'C'),
#              ('fixed_mod[15]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[15]-site', 'C'),
#              ('fixed_mod[16]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[16]-site', 'C'),
#              ('fixed_mod[17]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[17]-site', 'C'),
#              ('fixed_mod[18]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[18]-site', 'C'),
#              ('fixed_mod[19]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[19]-site', 'C'),
#              ('fixed_mod[20]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[20]-site', 'C'),
#              ('fixed_mod[21]', ('Carbamidomethyl', '57.02146530151367')),
#              ('fixed_mod[21]-site', 'C'),
#              ('variable_mod[1]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[1]-site', 'M'),
#              ('variable_mod[2]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[2]-site', 'M'),
#              ('variable_mod[3]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[3]-site', 'M'),
#              ('variable_mod[4]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[4]-site', 'M'),
#              ('variable_mod[5]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[5]-site', 'M'),
#              ('variable_mod[6]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[6]-site', 'M'),
#              ('variable_mod[7]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[7]-site', 'M'),
#              ('variable_mod[8]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[8]-site', 'M'),
#              ('variable_mod[9]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[9]-site', 'M'),
#              ('variable_mod[10]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[10]-site', 'M'),
#              ('variable_mod[11]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[11]-site', 'M'),
#              ('variable_mod[12]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[12]-site', 'M'),
#              ('variable_mod[13]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[13]-site', 'M'),
#              ('variable_mod[14]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[14]-site', 'M'),
#              ('variable_mod[15]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[15]-site', 'M'),
#              ('variable_mod[16]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[16]-site', 'M'),
#              ('variable_mod[17]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[17]-site', 'M'),
#              ('variable_mod[18]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[18]-site', 'M'),
#              ('variable_mod[19]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[19]-site', 'M'),
#              ('variable_mod[20]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[20]-site', 'M'),
#              ('variable_mod[21]', ('Oxidation', '15.994915008544922')),
#              ('variable_mod[21]-site', 'M'),
#              ('ms_run[1]-format', 'Mascot MGF file'),
#              ('ms_run[1]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_01.raw_(F019845).MGF'),
#              ('ms_run[1]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[2]-format', 'Mascot MGF file'),
#              ('ms_run[2]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_02.raw_(F019833).MGF'),
#              ('ms_run[2]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[3]-format', 'Mascot MGF file'),
#              ('ms_run[3]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_02.raw_(F019846).MGF'),
#              ('ms_run[3]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[4]-format', 'Mascot MGF file'),
#              ('ms_run[4]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_03.raw_(F019834).MGF'),
#              ('ms_run[4]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[5]-format', 'Mascot MGF file'),
#              ('ms_run[5]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_03.raw_(F019847).MGF'),
#              ('ms_run[5]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[6]-format', 'Mascot MGF file'),
#              ('ms_run[6]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_04.raw_(F019835).MGF'),
#              ('ms_run[6]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[7]-format', 'Mascot MGF file'),
#              ('ms_run[7]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_04.raw_(F019848).MGF'),
#              ('ms_run[7]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[8]-format', 'Mascot MGF file'),
#              ('ms_run[8]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_05.raw_(F019836).MGF'),
#              ('ms_run[8]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[9]-format', 'Mascot MGF file'),
#              ('ms_run[9]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_05.raw_(F019849).MGF'),
#              ('ms_run[9]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[10]-format', 'Mascot MGF file'),
#              ('ms_run[10]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_06.raw_(F019850).MGF'),
#              ('ms_run[10]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[11]-format', 'Mascot MGF file'),
#              ('ms_run[11]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_06.raw_(F019850_1).MGF'),
#              ('ms_run[11]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[12]-format', 'Mascot MGF file'),
#              ('ms_run[12]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_07.raw_(F019838).MGF'),
#              ('ms_run[12]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[13]-format', 'Mascot MGF file'),
#              ('ms_run[13]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_07.raw_(F019851).MGF'),
#              ('ms_run[13]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[14]-format', 'Mascot MGF file'),
#              ('ms_run[14]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_08.raw_(F019852).MGF'),
#              ('ms_run[14]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[15]-format', 'Mascot MGF file'),
#              ('ms_run[15]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_09.raw_(F019839).MGF'),
#              ('ms_run[15]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[16]-format', 'Mascot MGF file'),
#              ('ms_run[16]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_09.raw_(F019853).MGF'),
#              ('ms_run[16]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[17]-format', 'Mascot MGF file'),
#              ('ms_run[17]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_10.raw_(F019840).MGF'),
#              ('ms_run[17]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[18]-format', 'Mascot MGF file'),
#              ('ms_run[18]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_10.raw_(F019854).MGF'),
#              ('ms_run[18]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[19]-format', 'Mascot MGF file'),
#              ('ms_run[19]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_11.raw_(F019855).MGF'),
#              ('ms_run[19]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[20]-format', 'Mascot MGF file'),
#              ('ms_run[20]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_12.raw_(F019841_1).MGF'),
#              ('ms_run[20]-id_format', 'multiple peak list nativeID format'),
#              ('ms_run[21]-format', 'Mascot MGF file'),
#              ('ms_run[21]-location',
#               'file:D:\\DATA\\u0099839_nadia\\experiment1\\perspectives analysis\\2experimentos mzIdent export 23-sep-2015 03-10-37-PM\\2experimentos.mzid.gz_File_Name__nadia_sample_12.raw_(F019856).MGF'),
#              ('ms_run[21]-id_format', 'multiple peak list nativeID format'),
#              ('sample[1]-species[1]', 'Coffea arabica (Arabian coffee)'),
#              ('sample[1]-tissue[1]', 'cell suspension culture'),
#              ('sample[1]-cell_type[1]', 'plant cell'),
#              ('sample[1]-cell_type[2]', 'early embryonic cell'),
#              ('custom[1]', ('Date of export', 'Wed Sep 23 14:46:10 BST 2015')),
#              ('custom[2]',
#               ('Original converted file',
#                '/nfs/pride/prod/archive/PXD002963/internal/2experimentos.mzid')),
#              ('custom[3]',
#               ('Project title',
#                'Proteome profile of coffee embryogenic cell suspensions'))])

# %%
mztab.spectrum_match_table.columns
# Out:
# Index(['sequence', 'PSM_ID', 'accession', 'unique', 'database',
#        'database_version', 'search_engine', 'search_engine_score[1]',
#        'search_engine_score[2]', 'search_engine_score[3]',
#        'search_engine_score[4]', 'modifications', 'retention_time', 'charge',
#        'exp_mass_to_charge', 'calc_mass_to_charge', 'spectra_ref', 'pre',
#        'post', 'start', 'end', 'opt_global_mzidentml_original_ID',
#        'opt_global_cv_MS:1002217_decoy_peptide',
#        'opt_global_cv_PRIDE:0000091_rank'],
#       dtype='object')

# %%
mztab.spectrum_match_table[["accession","sequence","database",'pre', 'post', 'start', 'end',"spectra_ref"]]
# Out:
#                accession                 sequence  \
# PSM_ID
# 1       A0A068U1Z5_COFCA              VFGPHQWEILR
# 2       A0A068TTF0_COFCA     YLEDKTSVPYEPVYSDEQAR
# 3       A0A068TTF0_COFCA     YLEDKTSVPYEPVYSDEQAR
# 4       A0A068TTF0_COFCA     YLEDKTSVPYEPVYSDEQAR
# 5       A0A068TTF0_COFCA     YLEDKTSVPYEPVYSDEQAR
# ...                  ...                      ...
# 16925   A0A068UYE2_COFCA  LFILDYHDMLLPFIEGMNSLPGR
# 16926   A0A068VF06_COFCA        IVNKWNTALIGLMTYFR
# 16927   A0A068VF06_COFCA        IVNKWNTALIGLMTYFR
# 16926   A0A068V8A1_COFCA        IVNKWNTALIGLMTYFR
# 16927   A0A068V8A1_COFCA        IVNKWNTALIGLMTYFR
#
#                                database   pre  post  start   end  \
# PSM_ID
# 1       uniprot-taxonomy%3Acoffee.fasta  None  None    364   374
# 2       uniprot-taxonomy%3Acoffee.fasta  None  None    312   331
# 3       uniprot-taxonomy%3Acoffee.fasta  None  None    312   331
# 4       uniprot-taxonomy%3Acoffee.fasta  None  None    312   331
# 5       uniprot-taxonomy%3Acoffee.fasta  None  None    312   331
# ...                                 ...   ...   ...    ...   ...
# 16925   uniprot-taxonomy%3Acoffee.fasta  None  None    504   526
# 16926   uniprot-taxonomy%3Acoffee.fasta  None  None   1298  1314
# 16927   uniprot-taxonomy%3Acoffee.fasta  None  None   1298  1314
# 16926   uniprot-taxonomy%3Acoffee.fasta  None  None   1299  1315
# 16927   uniprot-taxonomy%3Acoffee.fasta  None  None   1299  1315
#
#                   spectra_ref
# PSM_ID
# 1         ms_run[3]:index=262
# 2        ms_run[8]:index=1954
# 3       ms_run[20]:index=1775
# 4       ms_run[17]:index=1996
# 5       ms_run[15]:index=1870
# ...                       ...
# 16925     ms_run[2]:index=654
# 16926     ms_run[2]:index=308
# 16927     ms_run[4]:index=226
# 16926     ms_run[2]:index=308
# 16927     ms_run[4]:index=226
#
# [19371 rows x 8 columns]

# %%
mztab.protein_table[['accession', 'description', 'taxid', 'species', 'database',
       'database_version', 'search_engine']]
# Out:
#                          accession  \
# accession
# A0A068U1Z5_COFCA  A0A068U1Z5_COFCA
# A0A068TTF0_COFCA  A0A068TTF0_COFCA
# A0A068U9U8_COFCA  A0A068U9U8_COFCA
# A0A068URX2_COFCA  A0A068URX2_COFCA
# A0A068TYH5_COFCA  A0A068TYH5_COFCA
# ...                            ...
# A0A068UX04_COFCA  A0A068UX04_COFCA
# A0A068ULJ5_COFCA  A0A068ULJ5_COFCA
# A0A068UYE2_COFCA  A0A068UYE2_COFCA
# A0A068VF06_COFCA  A0A068VF06_COFCA
# A0A068V8A1_COFCA  A0A068V8A1_COFCA
#
#                                                         description taxid  \
# accession
# A0A068U1Z5_COFCA  Eukaryotic translation initiation factor 3 sub...  None
# A0A068TTF0_COFCA  Coffea canephora DH200=94 genomic scaffold, sc...  None
# A0A068U9U8_COFCA  Coffea canephora DH200=94 genomic scaffold, sc...  None
# A0A068URX2_COFCA  ATP-dependent Clp protease proteolytic subunit...  None
# A0A068TYH5_COFCA  Coffea canephora DH200=94 genomic scaffold, sc...  None
# ...                                                             ...   ...
# A0A068UX04_COFCA  Coffea canephora DH200=94 genomic scaffold, sc...  None
# A0A068ULJ5_COFCA  Coffea canephora DH200=94 genomic scaffold, sc...  None
# A0A068UYE2_COFCA  Lipoxygenase OS=Coffea canephora GN=GSCOC_T000...  None
# A0A068VF06_COFCA  Coffea canephora DH200=94 genomic scaffold, sc...  None
# A0A068V8A1_COFCA  Coffea canephora DH200=94 genomic scaffold, sc...  None
#
#                  species                         database database_version  \
# accession
# A0A068U1Z5_COFCA    None  uniprot-taxonomy%3Acoffee.fasta             None
# A0A068TTF0_COFCA    None  uniprot-taxonomy%3Acoffee.fasta             None
# A0A068U9U8_COFCA    None  uniprot-taxonomy%3Acoffee.fasta             None
# A0A068URX2_COFCA    None  uniprot-taxonomy%3Acoffee.fasta             None
# A0A068TYH5_COFCA    None  uniprot-taxonomy%3Acoffee.fasta             None
# ...                  ...                              ...              ...
# A0A068UX04_COFCA    None  uniprot-taxonomy%3Acoffee.fasta             None
# A0A068ULJ5_COFCA    None  uniprot-taxonomy%3Acoffee.fasta             None
# A0A068UYE2_COFCA    None  uniprot-taxonomy%3Acoffee.fasta             None
# A0A068VF06_COFCA    None  uniprot-taxonomy%3Acoffee.fasta             None
# A0A068V8A1_COFCA    None  uniprot-taxonomy%3Acoffee.fasta             None
#
#                                  search_engine
# accession
# A0A068U1Z5_COFCA  [Mascot, X!Tandem, Scaffold]
# A0A068TTF0_COFCA  [Mascot, X!Tandem, Scaffold]
# A0A068U9U8_COFCA  [Mascot, X!Tandem, Scaffold]
# A0A068URX2_COFCA  [Mascot, X!Tandem, Scaffold]
# A0A068TYH5_COFCA  [Mascot, X!Tandem, Scaffold]
# ...                                        ...
# A0A068UX04_COFCA  [Mascot, X!Tandem, Scaffold]
# A0A068ULJ5_COFCA  [Mascot, X!Tandem, Scaffold]
# A0A068UYE2_COFCA  [Mascot, X!Tandem, Scaffold]
# A0A068VF06_COFCA  [Mascot, X!Tandem, Scaffold]
# A0A068V8A1_COFCA  [Mascot, X!Tandem, Scaffold]
#
# [1087 rows x 7 columns]
